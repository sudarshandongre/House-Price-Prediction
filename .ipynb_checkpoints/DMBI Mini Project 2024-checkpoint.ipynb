# %% [markdown]
# ## Business Intelligence
# Mini Project
#
# Group Topic** Mumbai House Price Predictio**
# Group Members** Soham Niungare, Nishad Bhujbal, Tanvi Mayekar, Sudarshan Dong*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("DataSet\mumbai.csv")

# %%
data
# Out:
#            price                                            Address    area  \
# 0     22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1     35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2     31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3     18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4     13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
# ...          ...                                                ...     ...
# 6250  19500000.0   Yari Road, Mumbai - Western Suburbs, Maharashtra   810.0
# 6251  22000000.0  502., Hari Om Nagar, Mumbai - North Mumbai, Ma...  1400.0
# 6252  20000000.0  Lokhandwala Complex, Andheri West, Lokhandwala...   750.0
# 6253  11000000.0         Sion, Mumbai - Central Mumbai, Maharashtra   700.0
# 6254  15000000.0    Mulund West, Mumbai - Central Line, Maharashtra   900.0
#
#        latitude  longitude  Bedrooms  Bathrooms  Balcony              Status  \
# 0     19.032800  72.896357       2.0        2.0      NaN  Under Construction
# 1     19.032800  72.896357       3.0        2.0      NaN  Under Construction
# 2     19.085600  72.909277       3.0        3.0      NaN  Under Construction
# 3     19.155756  72.846862       2.0        2.0      2.0       Ready to Move
# 4     19.177555  72.849887       2.0        2.0      NaN                 NaN
# ...         ...        ...       ...        ...      ...                 ...
# 6250  19.138320  72.810020       2.0        2.0      NaN       Ready to Move
# 6251  19.221920  72.854250       3.0        3.0      1.0       Ready to Move
# 6252  19.144320  72.824111       2.0        2.0      NaN       Ready to Move
# 6253  19.047201  72.872225       2.0        2.0      NaN       Ready to Move
# 6254  19.168818  72.936375       2.0        2.0      NaN       Ready to Move
#
#           neworold  parking Furnished_status  Lift  \
# 0     New Property      NaN              NaN   2.0
# 1     New Property      NaN              NaN   2.0
# 2     New Property      1.0              NaN   2.0
# 3     New Property      1.0              NaN   3.0
# 4     New Property      1.0      Unfurnished   2.0
# ...            ...      ...              ...   ...
# 6250        Resale      1.0   Semi-Furnished   NaN
# 6251        Resale      NaN      Unfurnished   NaN
# 6252        Resale      1.0              NaN   1.0
# 6253        Resale      NaN        Furnished   NaN
# 6254        Resale      NaN              NaN   NaN
#
#                               Landmarks type_of_building  \
# 0                                   NaN             Flat
# 1                                   NaN             Flat
# 2                                   NaN             Flat
# 3                        Laxmi Callista             Flat
# 4                near uper govind nagar             Flat
# ...                                 ...              ...
# 6250                                NaN             Flat
# 6251                                NaN             Flat
# 6252  Lokhandwala Complex, Andheri West             Flat
# 6253                                NaN             Flat
# 6254                                NaN             Flat
#
#                                                    desc    Price_sqft
# 0     \n\n\n                                Right fr...  35612.082671
# 1     \n\n\n                                Right fr...  35934.291581
# 2     \n                    \n                    \n...  32747.933884
# 3     \n\n\n                                Welcome ...  29729.729730
# 4     \n                    \n                    \n...  12385.321101
# ...                                                 ...           ...
# 6250  \n\n\n                                 This Mu...  24074.074074
# 6251  \n                    \n                    \n...  15714.285714
# 6252  \n\n\n                                 This Fr...  26666.666667
# 6253                                                 \n  15714.285714
# 6254                                                 \n  16666.666667
#
# [6255 rows x 17 columns]

# %%
data.shape
# Out:
# (6255, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6255 entries, 0 to 6254
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             6255 non-null   float64
#  1   Address           6255 non-null   object
#  2   area              6255 non-null   float64
#  3   latitude          6255 non-null   float64
#  4   longitude         6255 non-null   float64
#  5   Bedrooms          6255 non-null   float64
#  6   Bathrooms         6255 non-null   float64
#  7   Balcony           2376 non-null   float64
#  8   Status            5774 non-null   object
#  9   neworold          6255 non-null   object
#  10  parking           2129 non-null   float64
#  11  Furnished_status  3600 non-null   object
#  12  Lift              1678 non-null   float64
#  13  Landmarks         2617 non-null   object
#  14  type_of_building  6255 non-null   object
#  15  desc              6255 non-null   object
#  16  Price_sqft        6255 non-null   float64
# dtypes: float64(10), object(7)
# memory usage: 830.9+ KB

# %%
for column in data.columns:
  print(data[column].value_counts())
  print("_"*30)
# Out:
# price
# 15000000.0    183
# 25000000.0    165
# 20000000.0    157
# 18000000.0    157
# 16000000.0    135
#              ...
# 24800000.0      1
# 21300000.0      1
# 71500000.0      1
# 9450000.0       1
# 3880000.0       1
# Name: count, Length: 540, dtype: int64
# ______________________________
# Address
# Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                                 154
# Andheri West, Mumbai - Western Suburbs, Maharashtra                                                                   129
# Andheri East, Mumbai - Western Suburbs, Maharashtra                                                                    81
# Chembur, Mumbai - Harbour Line, Maharashtra                                                                            79
# Mulund West, Mumbai - Central Line, Maharashtra                                                                        78
#                                                                                                                      ...
# Mumbai, Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                           1
# 74, Sarayu, Narayan Guru hsg soc ltd. P.L.lokhande marg, Chembur, Mumbai - Harbour Line, Maharashtra                    1
# 120/46, Anandvan, Sector 1, Charkop, Kandivali West, Mumbai., Sector 1 Charkop, Mumbai - North Mumbai, Maharashtra      1
# Avenue H, Bld 27, Flat 701, Virar, Mumbai - Mira Road and Beyond, Maharashtra                                           1
# Lokhandwala Complex, Andheri West, Lokhandwala Complex, Mumbai - Western Suburbs, Maharashtra                           1
# Name: count, Length: 3632, dtype: int64
# ______________________________
# area
# 1000.0    282
# 900.0     217
# 1100.0    210
# 1200.0    184
# 850.0     177
#          ...
# 1542.0      1
# 6200.0      1
# 2265.0      1
# 991.0       1
# 722.0       1
# Name: count, Length: 933, dtype: int64
# ______________________________
# latitude
# 19.129738    112
# 19.282170    110
# 19.209944     73
# 19.032800     68
# 19.233532     60
#             ...
# 18.980853      1
# 19.014231      1
# 19.048122      1
# 19.146906      1
# 19.168818      1
# Name: count, Length: 2465, dtype: int64
# ______________________________
# longitude
# 72.829155    112
# 72.876540    110
# 72.830869     73
# 72.869271     72
# 72.896357     68
#             ...
# 72.895983      1
# 72.856386      1
# 72.863892      1
# 72.841916      1
# 72.936375      1
# Name: count, Length: 2387, dtype: int64
# ______________________________
# Bedrooms
# 2.0     4097
# 3.0     1676
# 4.0      364
# 5.0       76
# 6.0       26
# 7.0        9
# 8.0        4
# 10.0       3
# Name: count, dtype: int64
# ______________________________
# Bathrooms
# 2.0     4335
# 3.0     1387
# 4.0      382
# 5.0      106
# 6.0       33
# 7.0        5
# 8.0        5
# 10.0       1
# 0.0        1
# Name: count, dtype: int64
# ______________________________
# Balcony
# 1.0    949
# 2.0    583
# 3.0    468
# 4.0    297
# 5.0     56
# 6.0     12
# 7.0      8
# 8.0      3
# Name: count, dtype: int64
# ______________________________
# Status
# Ready to Move         5771
# Under Construction       3
# Name: count, dtype: int64
# ______________________________
# neworold
# Resale          5515
# New Property     740
# Name: count, dtype: int64
# ______________________________
# parking
# 1.0      1421
# 2.0       509
# 3.0        87
# 4.0        33
# 5.0         9
# 10.0        9
# 20.0        5
# 12.0        4
# 18.0        3
# 30.0        3
# 6.0         3
# 14.0        2
# 15.0        2
# 9.0         2
# 401.0       2
# 7.0         2
# 40.0        2
# 205.0       2
# 105.0       2
# 11.0        2
# 104.0       2
# 65.0        1
# 24.0        1
# 601.0       1
# 22.0        1
# 60.0        1
# 26.0        1
# 801.0       1
# 102.0       1
# 302.0       1
# 125.0       1
# 163.0       1
# 418.0       1
# 101.0       1
# 21.0        1
# 702.0       1
# 55.0        1
# 202.0       1
# 150.0       1
# 185.0       1
# 75.0        1
# 603.0       1
# 8.0         1
# 16.0        1
# Name: count, dtype: int64
# ______________________________
# Furnished_status
# Unfurnished       1384
# Semi-Furnished    1195
# Furnished         1021
# Name: count, dtype: int64
# ______________________________
# Lift
# 2.0     758
# 1.0     327
# 3.0     220
# 4.0     174
# 0.0      55
# 5.0      51
# 6.0      49
# 7.0      18
# 8.0      11
# 10.0     11
# 9.0       4
# Name: count, dtype: int64
# ______________________________
# Landmarks
# Country Club                         4
# Near Western Express Highway         4
# Near D Mart                          3
# Near Versova Telephone Exchange      3
# Near Evita Empress                   3
#                                     ..
# Near Rasraj Hotel                    1
# Near Maruti Business Park            1
# Near Janki Devi Public school        1
# Near Phoenix Mall                    1
# Lokhandwala Complex, Andheri West    1
# Name: count, Length: 2555, dtype: int64
# ______________________________
# type_of_building
# Flat                5828
# Individual House     427
# Name: count, dtype: int64
# ______________________________
# desc
# \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2581
# \n                    \n                    \n                    \n                       Multistorey apartment is available for sale. It is a good location property. Please contact for more details.\n                    \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                      107
# \n                    \n                    \n                    \n                       Multistorey apartment is available for sale.it is a good location property. Please contact for more details.\n                    \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                        23
# \n                    \n                    \n                    \n                       property is in a good locality\n                    \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      16
# \n                    \n                    \n                    \n                       It is a nice house with good facilities\n                    \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             15
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# \n                    \n                    \n                    \n                       Location Conmectivity\n                    \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# \n\n\n                                 The Unit consists of 2 furnished bathroom and also has 2 spacious balconies. This is a 2 bed room apartment present in Mahim West. It measures 1000 Sq-ft of covered area. The Value of the Unit is fixed at 3. 30 Cr. It lies on second level of the 3 floors in all and is well ventilated.\n                            \nmore\n\n                                                                                                                                                                                                                                                                                                                            1
# \n                    \n                    \n                    \n                       2 toilets available in the apartment\n                    \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# \n\n\n                                2bhk with huge terrace. Total useable area of 1140 sqft.  1. Master Bedroom   bathroom along with terrace. 2. 2nd Bedroom   bathroom along with big balcony. 3. Living  Hall room  4. Dining area. 5. Fully furnished Kitchen with connections. 6. Laundry room. 7. Terrace accessible from all rooms. 8. 1 Car parking wt 2 bike parking. 9. Gated Society with high security levels. 10. Childrens play area. Ideally best for families. Gujarati  Jain majority area.  Everyone is welcome thou. 1  5 min walk from D’mart, Maxus Mall, Domino’s, Mac d, Gym, Jain Temple. Ready to Move in. Ad posted by Owner.\n                            \nmore\n\n       1
# \n\n\n                                 This Freehold Multistorey Apartment at 1st floor overlooks Garden/Park offering a beautiful view from the house. with airy interiors. Ample space for covered car parking for residents. The Multistorey Apartment construction is above 20 years. Flooring of type Vitrified covers maximum part of the house. \n                            \nmore\n\n                                                                                                                                                                                                                                                                                                         1
# Name: count, Length: 3445, dtype: int64
# ______________________________
# Price_sqft
# 20000.000000    104
# 25000.000000     64
# 33333.333333     48
# 16666.666667     46
# 10000.000000     39
#                ...
# 8750.000000       1
# 20670.391061      1
# 9729.729730       1
# 14440.433213      1
# 4127.659574       1
# Name: count, Length: 3582, dtype: int64
# ______________________________

# %%
data.isna().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             3879
# Status               481
# neworold               0
# parking             4126
# Furnished_status    2655
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
data.drop(columns=['Landmarks', 'Lift','Furnished_status','parking','Balcony'], inplace=True)

# %%
data['Status'].value_counts()
# Out:
# Status
# Ready to Move         5771
# Under Construction       3
# Name: count, dtype: int64

# %%
data["Status"] = data["Status"].fillna("Under Construction")

# %%
data.isna().sum()
# Out:
# price               0
# Address             0
# area                0
# latitude            0
# longitude           0
# Bedrooms            0
# Bathrooms           0
# Status              0
# neworold            0
# type_of_building    0
# desc                0
# Price_sqft          0
# dtype: int64

# %% [markdown]
# # Feature Selection

# %%
originalFeatures = data.columns

# %%
print("Original Features count: ", len(originalFeatures))
print("Original Features: ", originalFeatures)
data.head()
# Out:
# Original Features count:  12
# Original Features:  Index(['price', 'Address', 'area', 'latitude', 'longitude', 'Bedrooms',
#        'Bathrooms', 'Status', 'neworold', 'type_of_building', 'desc',
#        'Price_sqft'],
#       dtype='object')
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#     latitude  longitude  Bedrooms  Bathrooms              Status  \
# 0  19.032800  72.896357       2.0        2.0  Under Construction
# 1  19.032800  72.896357       3.0        2.0  Under Construction
# 2  19.085600  72.909277       3.0        3.0  Under Construction
# 3  19.155756  72.846862       2.0        2.0       Ready to Move
# 4  19.177555  72.849887       2.0        2.0  Under Construction
#
#        neworold type_of_building  \
# 0  New Property             Flat
# 1  New Property             Flat
# 2  New Property             Flat
# 3  New Property             Flat
# 4  New Property             Flat
#
#                                                 desc    Price_sqft
# 0  \n\n\n                                Right fr...  35612.082671
# 1  \n\n\n                                Right fr...  35934.291581
# 2  \n                    \n                    \n...  32747.933884
# 3  \n\n\n                                Welcome ...  29729.729730
# 4  \n                    \n                    \n...  12385.321101

# %%
#First, lets check out the longitude and latitude columns.
alpha = 0.02
plt.figure(figsize=(10,10))
# Ioc_x and Loc_y
plt.subplot (121)
plt.scatter(data.longitude, data.latitude, color='blue',alpha=alpha)
plt.title("longitude and latitude")
# Out:
# Text(0.5, 1.0, 'longitude and latitude')

# %%
plt.figure(figsize=(5,5))

plt.scatter(data.Bathrooms, data.Bedrooms, c=data.Bedrooms, cmap='viridis')
plt.title("Bedrooms and Bathrooms")
# Out:
# Text(0.5, 1.0, 'Bedrooms and Bathrooms')

# %%
data['desc']
# Out:
# 0       \n\n\n                                Right fr...
# 1       \n\n\n                                Right fr...
# 2       \n                    \n                    \n...
# 3       \n\n\n                                Welcome ...
# 4       \n                    \n                    \n...
#                               ...
# 6250    \n\n\n                                 This Mu...
# 6251    \n                    \n                    \n...
# 6252    \n\n\n                                 This Fr...
# 6253                                                   \n
# 6254                                                   \n
# Name: desc, Length: 6255, dtype: object

# %%
data.drop(columns=['desc'], inplace=True)

# %%
data.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#     latitude  longitude  Bedrooms  Bathrooms              Status  \
# 0  19.032800  72.896357       2.0        2.0  Under Construction
# 1  19.032800  72.896357       3.0        2.0  Under Construction
# 2  19.085600  72.909277       3.0        3.0  Under Construction
# 3  19.155756  72.846862       2.0        2.0       Ready to Move
# 4  19.177555  72.849887       2.0        2.0  Under Construction
#
#        neworold type_of_building    Price_sqft
# 0  New Property             Flat  35612.082671
# 1  New Property             Flat  35934.291581
# 2  New Property             Flat  32747.933884
# 3  New Property             Flat  29729.729730
# 4  New Property             Flat  12385.321101

# %%
data['bhk'] = data['area'] / 500

# %%
data['Address'].value_counts()
# Out:
# Address
# Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                                 154
# Andheri West, Mumbai - Western Suburbs, Maharashtra                                                                   129
# Andheri East, Mumbai - Western Suburbs, Maharashtra                                                                    81
# Chembur, Mumbai - Harbour Line, Maharashtra                                                                            79
# Mulund West, Mumbai - Central Line, Maharashtra                                                                        78
#                                                                                                                      ...
# Mumbai, Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                           1
# 74, Sarayu, Narayan Guru hsg soc ltd. P.L.lokhande marg, Chembur, Mumbai - Harbour Line, Maharashtra                    1
# 120/46, Anandvan, Sector 1, Charkop, Kandivali West, Mumbai., Sector 1 Charkop, Mumbai - North Mumbai, Maharashtra      1
# Avenue H, Bld 27, Flat 701, Virar, Mumbai - Mira Road and Beyond, Maharashtra                                           1
# Lokhandwala Complex, Andheri West, Lokhandwala Complex, Mumbai - Western Suburbs, Maharashtra                           1
# Name: count, Length: 3632, dtype: int64

# %%
data['Address'] = data['Address'].apply(lambda x: x.strip())
location_count = data['Address'].value_counts()

# %%
location_count
# Out:
# Address
# Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                                 154
# Andheri West, Mumbai - Western Suburbs, Maharashtra                                                                   129
# Andheri East, Mumbai - Western Suburbs, Maharashtra                                                                    81
# Chembur, Mumbai - Harbour Line, Maharashtra                                                                            79
# Mulund West, Mumbai - Central Line, Maharashtra                                                                        78
#                                                                                                                      ...
# Mumbai, Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                           1
# 74, Sarayu, Narayan Guru hsg soc ltd. P.L.lokhande marg, Chembur, Mumbai - Harbour Line, Maharashtra                    1
# 120/46, Anandvan, Sector 1, Charkop, Kandivali West, Mumbai., Sector 1 Charkop, Mumbai - North Mumbai, Maharashtra      1
# Avenue H, Bld 27, Flat 701, Virar, Mumbai - Mira Road and Beyond, Maharashtra                                           1
# Lokhandwala Complex, Andheri West, Lokhandwala Complex, Mumbai - Western Suburbs, Maharashtra                           1
# Name: count, Length: 3632, dtype: int64

# %%
location_count_less_10 = location_count[location_count <= 10]
location_count_less_10
# Out:
# Address
# Virar East, Mumbai - Mira Road and Beyond, Maharashtra                                                                10
# Dadar West, Mumbai - South Mumbai, Maharashtra                                                                        10
# Chembur East, Mumbai, Maharashtra                                                                                     10
# Dadar East, Mumbai - Central Mumbai, Maharashtra                                                                      10
# Wadala, Mumbai - Harbour Line, Maharashtra                                                                            10
#                                                                                                                       ..
# Mumbai, Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                                                          1
# 74, Sarayu, Narayan Guru hsg soc ltd. P.L.lokhande marg, Chembur, Mumbai - Harbour Line, Maharashtra                   1
# 120/46, Anandvan, Sector 1, Charkop, Kandivali West, Mumbai., Sector 1 Charkop, Mumbai - North Mumbai, Maharashtra     1
# Avenue H, Bld 27, Flat 701, Virar, Mumbai - Mira Road and Beyond, Maharashtra                                          1
# Lokhandwala Complex, Andheri West, Lokhandwala Complex, Mumbai - Western Suburbs, Maharashtra                          1
# Name: count, Length: 3573, dtype: int64

# %%
data['Address']= data['Address'].apply(lambda x: 'other' if x in location_count_less_10 else x)

# %%
data['Address'].value_counts()
# Out:
# Address
# other                                                                          4343
# Mira Road, Mumbai - Mira Road and Beyond, Maharashtra                           154
# Andheri West, Mumbai - Western Suburbs, Maharashtra                             129
# Andheri East, Mumbai - Western Suburbs, Maharashtra                              81
# Chembur, Mumbai - Harbour Line, Maharashtra                                      79
# Mulund West, Mumbai - Central Line, Maharashtra                                  78
# Kandivali West, Mumbai - North Mumbai, Maharashtra                               70
# Malad West, Mumbai - Western Suburbs, Maharashtra                                69
# Borivali West, Mumbai - Western Suburbs, Maharashtra                             64
# Virar West, Mumbai - Mira Road and Beyond, Maharashtra                           60
# Kandivali East, Mumbai - North Mumbai, Maharashtra                               52
# Goregaon West, Mumbai - North Mumbai, Maharashtra                                44
# Goregaon East, Mumbai - Western Suburbs, Maharashtra                             41
# Ghatkopar West, Mumbai - Central Line, Maharashtra                               40
# Bhandup West, Mumbai - Central Line, Maharashtra                                 40
# Malad East, Mumbai - North Mumbai, Maharashtra                                   38
# Borivali East, Mumbai - Western Suburbs, Maharashtra                             35
# Powai, Mumbai - Central Line, Maharashtra                                        33
# Dahisar East, Mumbai - North Mumbai, Maharashtra                                 33
# Santacruz West, Mumbai - Western Suburbs, Maharashtra                            32
# Vile Parle East, Mumbai - Western Suburbs, Maharashtra                           31
# Kalyan, Mumbai - Around Mumbai, Maharashtra                                      30
# Virar, Mumbai - Mira Road and Beyond, Maharashtra                                30
# Ghatkopar East, Mumbai - Central Line, Maharashtra                               29
# Parel, Mumbai - South Mumbai, Maharashtra                                        27
# Mulund East, Mumbai - Central Line, Maharashtra                                  26
# Ulhasnagar, Mumbai - Around Mumbai, Maharashtra                                  26
# Worli, Mumbai - South Mumbai, Maharashtra                                        25
# Vasai East, Mumbai - Mira Road and Beyond, Maharashtra                           24
# Mira Road, Mumbai, Mira Road, Mumbai - Mira Road and Beyond, Maharashtra         24
# Vasai West, Mumbai - Mira Road and Beyond, Maharashtra                           23
# Santacruz East, Mumbai - Western Suburbs, Maharashtra                            22
# Bandra West, Mumbai - Western Suburbs, Maharashtra                               21
# Marol, Mumbai - Western Suburbs, Maharashtra                                     21
# Vasai, Mumbai - Mira Road and Beyond, Maharashtra                                21
# Juhu, Mumbai - Western Suburbs, Maharashtra                                      21
# Worli, Mumbai, Worli, Mumbai - South Mumbai, Maharashtra                         19
# Chandivali, Mumbai - Central Line, Maharashtra                                   19
# Mulund West, Mumbai, Mulund West, Mumbai - Central Line, Maharashtra             18
# Khar West, Mumbai - Western Suburbs, Maharashtra                                 18
# Bhayandar West, Mumbai - Mira Road and Beyond, Maharashtra                       18
# Mira Bhayandar, Mumbai - Mira Road and Beyond, Maharashtra                       17
# Prabhadevi, Mumbai - South Mumbai, Maharashtra                                   16
# Thane-Kalyan-Dombivli, Mumbai, Maharashtra                                       15
# Tilak Nagar - Harbour Line, Mumbai - Harbour Line, Maharashtra                   15
# Vile Parle West, Mumbai - Western Suburbs, Maharashtra                           15
# Sion, Mumbai - Central Mumbai, Maharashtra                                       15
# Lokhandwala Complex, Mumbai - Western Suburbs, Maharashtra                       14
# Ambernath, Mumbai, Maharashtra                                                   13
# Thane, Mumbai, Maharashtra                                                       13
# Kanjurmarg East, Mumbai - Central Line, Maharashtra                              12
# Bhayandar East, Mumbai - Mira Road and Beyond, Maharashtra                       12
# Goregaon East, Mumbai, Goregaon East, Mumbai - Western Suburbs, Maharashtra      12
# Malad West, Mumbai, Malad West, Mumbai - Western Suburbs, Maharashtra            12
# Mahim West, Mumbai - Central Mumbai, Maharashtra                                 11
# Kandivali East, Mumbai, Thakur Village, Mumbai - North Mumbai, Maharashtra       11
# Bandra East, Mumbai - Western Suburbs, Maharashtra                               11
# Oshiwara, Mumbai - Western Suburbs, Maharashtra                                  11
# Charkop, Mumbai - North Mumbai, Maharashtra                                      11
# Andheri East, Mumbai, Andheri East, Mumbai - Western Suburbs, Maharashtra        11
# Name: count, dtype: int64

# %%
data
# Out:
#            price                                            Address    area  \
# 0     22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1     35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2     31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3     18700000.0                                              other   629.0
# 4     13500000.0                                              other  1090.0
# ...          ...                                                ...     ...
# 6250  19500000.0                                              other   810.0
# 6251  22000000.0                                              other  1400.0
# 6252  20000000.0                                              other   750.0
# 6253  11000000.0         Sion, Mumbai - Central Mumbai, Maharashtra   700.0
# 6254  15000000.0    Mulund West, Mumbai - Central Line, Maharashtra   900.0
#
#        latitude  longitude  Bedrooms  Bathrooms              Status  \
# 0     19.032800  72.896357       2.0        2.0  Under Construction
# 1     19.032800  72.896357       3.0        2.0  Under Construction
# 2     19.085600  72.909277       3.0        3.0  Under Construction
# 3     19.155756  72.846862       2.0        2.0       Ready to Move
# 4     19.177555  72.849887       2.0        2.0  Under Construction
# ...         ...        ...       ...        ...                 ...
# 6250  19.138320  72.810020       2.0        2.0       Ready to Move
# 6251  19.221920  72.854250       3.0        3.0       Ready to Move
# 6252  19.144320  72.824111       2.0        2.0       Ready to Move
# 6253  19.047201  72.872225       2.0        2.0       Ready to Move
# 6254  19.168818  72.936375       2.0        2.0       Ready to Move
#
#           neworold type_of_building    Price_sqft    bhk
# 0     New Property             Flat  35612.082671  1.258
# 1     New Property             Flat  35934.291581  1.948
# 2     New Property             Flat  32747.933884  1.936
# 3     New Property             Flat  29729.729730  1.258
# 4     New Property             Flat  12385.321101  2.180
# ...            ...              ...           ...    ...
# 6250        Resale             Flat  24074.074074  1.620
# 6251        Resale             Flat  15714.285714  2.800
# 6252        Resale             Flat  26666.666667  1.500
# 6253        Resale             Flat  15714.285714  1.400
# 6254        Resale             Flat  16666.666667  1.800
#
# [6255 rows x 12 columns]

# %%
def round_up_if_gt_0_5(x):
  return int(x + (x % 1 > 0.5))

# %%
data['bhk'] = data['bhk'].apply(round_up_if_gt_0_5)

# %%
data.describe()
# Out:
#               price         area     latitude    longitude     Bedrooms  \
# count  6.255000e+03  6255.000000  6255.000000  6255.000000  6255.000000
# mean   2.684187e+07  1185.625260    19.156772    72.868642     2.452278
# std    2.788831e+07   636.973259     0.109447     0.058614     0.749534
# min    1.500000e+06   503.000000    18.873713    72.754080     2.000000
# 25%    1.300000e+07   846.500000    19.081509    72.832930     2.000000
# 50%    1.900000e+07  1000.000000    19.147269    72.858019     2.000000
# 75%    3.000000e+07  1300.000000    19.213054    72.884691     3.000000
# max    3.600000e+08  8000.000000    19.476239    73.197823    10.000000
#
#          Bathrooms     Price_sqft          bhk
# count  6255.000000    6255.000000  6255.000000
# mean      2.425580   21422.923601     2.352678
# std       0.762604   12698.478665     1.303484
# min       0.000000    1500.000000     1.000000
# 25%       2.000000   13709.934735     2.000000
# 50%       2.000000   19285.714286     2.000000
# 75%       3.000000   26500.000000     3.000000
# max      10.000000  119047.619048    16.000000

# %%
plt.figure(figsize=(5,5))

plt.scatter(data.price, data.bhk, c=data.price, cmap='viridis')
plt.title("BHK and Price")
# Out:
# Text(0.5, 1.0, 'BHK and Price')

# %%
plt.figure(figsize=(5,5))
plt.scatter(data.price, data.area, c=data.price, cmap='viridis')
plt.title("Area and Price")
# Out:
# Text(0.5, 1.0, 'Area and Price')

# %%
data['price'].describe()
# Out:
# count    6.255000e+03
# mean     2.684187e+07
# std      2.788831e+07
# min      1.500000e+06
# 25%      1.300000e+07
# 50%      1.900000e+07
# 75%      3.000000e+07
# max      3.600000e+08
# Name: price, dtype: float64

# %%
data['price'] = data['price'] / 100000

# %%
data['price'].describe()
# Out:
# count    6255.000000
# mean      268.418737
# std       278.883107
# min        15.000000
# 25%       130.000000
# 50%       190.000000
# 75%       300.000000
# max      3600.000000
# Name: price, dtype: float64

# %% [markdown]
# # Cleaned Data

# %%
data.head()
# Out:
#    price                                            Address    area  \
# 0  224.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  350.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  317.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  187.0                                              other   629.0
# 4  135.0                                              other  1090.0
#
#     latitude  longitude  Bedrooms  Bathrooms              Status  \
# 0  19.032800  72.896357       2.0        2.0  Under Construction
# 1  19.032800  72.896357       3.0        2.0  Under Construction
# 2  19.085600  72.909277       3.0        3.0  Under Construction
# 3  19.155756  72.846862       2.0        2.0       Ready to Move
# 4  19.177555  72.849887       2.0        2.0  Under Construction
#
#        neworold type_of_building    Price_sqft  bhk
# 0  New Property             Flat  35612.082671    1
# 1  New Property             Flat  35934.291581    2
# 2  New Property             Flat  32747.933884    2
# 3  New Property             Flat  29729.729730    1
# 4  New Property             Flat  12385.321101    2

# %%
data.to_csv("./DataSet/Cleaned_data.csv")

# %%
X = data.drop(columns=['price'])
Y = data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5004, 11)
# (1251, 11)

# %% [markdown]
# # Applying Linear Regression

# %%
column_trans = make_column_transformer((OneHotEncoder(), ['Address', 'Status', 'neworold', 'type_of_building']), remainder='passthrough')

# %%
scalar  = StandardScaler(with_mean=False)

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans,scalar,lr)

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['Address', 'Status',
#                                                    'neworold',
#                                                    'type_of_building'])])),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('linearregression', LinearRegression())])

# %%
Y_pred_lr = pipe.predict(X_test)

# %%
r2_score(Y_test,Y_pred_lr)
# Out:
# 0.8577801286352389

# %% [markdown]
# # Applying Lasso Regression

# %%
lasso = Lasso()

# %%
pipe = make_pipeline(column_trans,scalar,lasso)

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['Address', 'Status',
#                                                    'neworold',
#                                                    'type_of_building'])])),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('lasso', Lasso())])

# %%
Y_pred_lasso = pipe.predict(X_test)

# %%
r2_score(Y_test,Y_pred_lasso)
# Out:
# 0.8576961635986617

# %% [markdown]
# # Applying Ridge Regression

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(column_trans, scalar,ridge)

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['Address', 'Status',
#                                                    'neworold',
#                                                    'type_of_building'])])),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('ridge', Ridge())])

# %%
Y_pred_ridge = pipe.predict(X_test)

# %%
r2_score(Y_test,Y_pred_ridge)
# Out:
# 0.8577596839133067

# %% [markdown]
# # Comparing All Algo

# %%
print("Linear Regression: ", r2_score(Y_test,Y_pred_lr))
print("Lasso Regression: ", r2_score(Y_test, Y_pred_lasso))
print("Ridge Regression: ", r2_score(Y_test, Y_pred_ridge))
# Out:
# Linear Regression:  0.8577801286352389
# Lasso Regression:  0.8576961635986617
# Ridge Regression:  0.8577596839133067

# %%
import pickle

# %%
pickle.dump(pipe,open("Model.pkl",'wb'))
